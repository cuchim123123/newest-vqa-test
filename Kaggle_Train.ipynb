# %%
# Cell 1: Setup
# !git clone https://github.com/cuchim123123/newest-vqa-test.git /kaggle/working/vqa
# !pip install -q -r /kaggle/working/vqa/requirements.txt

# %%
# Cell 2: Train (re-run this cell to resume after timeout)
# %cd /kaggle/working/vqa
# !python run_full_training.py
